# %%
import os

# %%
import json

# %%
data_files = os.listdir("03")

# %%
data = json.load(open(dpath))

# %%
data_file_paths = [os.path.join("03",i) for i in data_files]

# %%
temp_key_count = 0
for i in data_file_paths:
    temp_dict = json.load(open(i))
    if temp_key_count != len(temp_dict.keys()):
        print(f'{i} dosyasi anahtar kelime sayisi fazla {len(temp_dict.keys())}')
        temp_key_count = len(temp_dict.keys())
# Out:
# 03\data0.json dosyasi anahtar kelime sayisi fazla 16
# 03\data21.json dosyasi anahtar kelime sayisi fazla 17
# 03\data3.json dosyasi anahtar kelime sayisi fazla 16
# 03\data30.json dosyasi anahtar kelime sayisi fazla 17
# 03\data4.json dosyasi anahtar kelime sayisi fazla 16
# 03\data40.json dosyasi anahtar kelime sayisi fazla 67
# 03\data5.json dosyasi anahtar kelime sayisi fazla 16
# 03\data50.json dosyasi anahtar kelime sayisi fazla 67
# 03\data6.json dosyasi anahtar kelime sayisi fazla 16
# 03\data60.json dosyasi anahtar kelime sayisi fazla 67
# 03\data7.json dosyasi anahtar kelime sayisi fazla 16
# 03\data70.json dosyasi anahtar kelime sayisi fazla 67
# 03\data8.json dosyasi anahtar kelime sayisi fazla 16
# 03\data80.json dosyasi anahtar kelime sayisi fazla 67
# 03\data9.json dosyasi anahtar kelime sayisi fazla 16
# 03\data90.json dosyasi anahtar kelime sayisi fazla 67

# %%
a = json.load(open(os.path.join("03","data9.json")))
b = json.load(open(os.path.join("03","data21.json")))
c = json.load(open(os.path.join("03","data40.json")))

# %%
a.keys()
# Out:
# dict_keys(['TEKİRDAĞ', 'MARMARAEREĞLİSİ', 'ÇERKEZKÖY', 'ŞARKÖY/GANOS DAĞI', 'ERGENE/VAKIFLAR BELDESİ', 'HAYRABOLU', 'KAPAKLI', 'MALKARA', 'MALKARA/DOĞANKÖY', 'MARMARA EREĞLİSİ BAL.BAR.ANA MENDİREK FENERİ', 'MURATLI', 'SÜLEYMANPAŞA/BANARLI MAHALLESİ', 'TEKİRDAĞ ÇORLU HAVALİMANI', 'TEKİRDAĞ/SARAY', 'ÇORLU', 'ŞARKÖY'])

# %%
b.keys()
# Out:
# dict_keys(['TEKİRDAĞ', 'MARMARAEREĞLİSİ', 'ÇERKEZKÖY', 'ŞARKÖY/GANOS DAĞI', 'ERGENE/VAKIFLAR BELDESİ', 'HAYRABOLU', 'KAPAKLI', 'MALKARA', 'MALKARA/DOĞANKÖY', 'MARMARA EREĞLİSİ BAL.BAR.ANA MENDİREK FENERİ', 'MURATLI', 'SÜLEYMANPAŞA/BANARLI MAHALLESİ', 'TEKİRDAĞ ÇORLU HAVALİMANI', 'TEKİRDAĞ/SARAY', 'ÇORLU', 'ŞARKÖY', 'NoInfo'])

# %%
b
# Out:
# {'TEKİRDAĞ': {'elevation': '4',
#   'measurement': {'06 Mayıs - 00.40': {'weather': 'Çok Bulutlu',
#     'temperature': '14,1',
#     'rainfall': '0,0',
#     'wind': 'transform: rotate(316deg);',
#     'windspeed': '6',
#     'humidty': '73',
#     'pressureAct': '1013,9',
#     'pressureRed': '1014,3'},
#    '06 Mayıs - 00.49': {'weather': 'Çok Bulutlu',
#     'temperature': '14,1',
#     'rainfall': '0,0',
#     'wind': 'transform: rotate(318deg);',
#     'windspeed': '3',
#     'humidty': '74',
#     'pressureAct': '1013,9',
#     'pressureRed': '1014,3'},
#    '06 Mayıs - 01.04': {'weather': 'Çok Bulutlu',
#     'temperature': '14,0',
#     'rainfall': '0,0',
#     'wind': 'transform: rotate(318deg);',
#     'windspeed': '7',
#     'humidty': '75',
#     'pressureAct': '1013,9',
#     'pressureRed': '1014,3'},
#    '06 Mayıs - 01.28': {'weather': 'Çok Bulutlu',
#     'temperature': '13,6',
#     'rainfall': '0,0',
#     'wind': 'transform: rotate(240deg);',
# ...
